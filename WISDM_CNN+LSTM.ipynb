# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy import stats
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GroupKFold
from imblearn.over_sampling import RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight
import seaborn as sns
import torch.nn.functional as F

# %% [markdown]
# ## 데이터 로드 / EDA / 전처리

# %% [markdown]
# ### 데이터 로드

# %%
file = open("C:/Users/c/Desktop/ML programming/WISDM_ar_v1.1_raw.txt")

# %%
lines = file.readlines()

processedList = []

for i, line in enumerate(lines):
    try:
        line = line.split(',')
        last = line[5].split(';')[0]
        last = last.strip()
        if last == '':
            break;
        temp = [line[0], line[1], line[2], line[3], line[4], last]
        processedList.append(temp)
    except:
        print('Error at line number: ', i)
# Out:
# Error at line number:  281873
# Error at line number:  281874
# Error at line number:  281875

# %%
# 컬럼 추가
columns = ['user', 'activity', 'time', 'x', 'y', 'z']

# %%
df = pd.DataFrame(data = processedList, columns = columns)
df['x'] = df['x'].astype('float')
df['y'] = df['y'].astype('float')
df['z'] = df['z'].astype('float')
df['user'] = df['user'].astype('int')
df.head()
# Out:
#    user activity            time         x          y         z
# 0    33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1    33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2    33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3    33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4    33  Jogging  49106332290000 -1.184970  12.108489  7.205164

# %% [markdown]
# ### EDA

# %%
df.isnull().sum()
# Out:
# user        0
# activity    0
# time        0
# x           0
# y           0
# z           0
# dtype: int64

# %%
df['activity'].value_counts()
# Out:
# activity
# Walking       137375
# Jogging       129392
# Upstairs       35137
# Downstairs     33358
# Sitting         4599
# Standing        3555
# Name: count, dtype: int64

# %%
user_counts = df['user'].value_counts()

plt.figure(figsize=(16, 8)) 
barplot = sns.barplot(x=user_counts.index, y=user_counts.values, palette='viridis')

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 9),
                     textcoords = 'offset points')

plt.title('Number of Data Points per User', fontsize=16)
plt.xlabel('User ID', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\3400418400.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=user_counts.index, y=user_counts.values, palette='viridis')

# %%
user_counts = df['user'].value_counts()

group_a_mask = (user_counts.index >= 6) & (user_counts.index <= 27)
group_a_sum = user_counts[group_a_mask].sum()

group_b_mask = (user_counts.index >= 29) & (user_counts.index <= 36)
group_b_sum = user_counts[group_b_mask].sum()

plt.figure(figsize=(8, 6))
comparison_df = pd.DataFrame({
    'Group': ['Users 6-27', 'Users 29-36'],
    'Total Count': [group_a_sum, group_b_sum]
})
barplot = sns.barplot(x='Group', y='Total Count', data=comparison_df, palette='rocket')

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha = 'center', va = 'center',
                     xytext = (0, 9),
                     textcoords = 'offset points')

plt.title('Comparison of Data Counts Between User Groups', fontsize=16)
plt.ylabel('Total Number of Data Points', fontsize=12)
plt.xlabel('User Group', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1733336201.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='Group', y='Total Count', data=comparison_df, palette='rocket')

# %%
g = sns.catplot(data=df, y='activity', col='user', kind='count', 
                height=5, aspect=1, col_wrap=4, sharey=False)

g.fig.suptitle('Activity Counts per User', y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %% [markdown]
# ### 전처리

# %%
test_df = df[df['user'] > 27]
train_df = df[df['user'] <= 27]
test_df.shape, train_df.shape
# Out:
# ((141681, 6), (201735, 6))

# %%
def feature_engineering(df):
    df['magnitude'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)
        
    feature_cols = ['x', 'y', 'z', 'magnitude']
    for col in feature_cols:

        df[f'{col}_std'] = df.groupby('user')[col].rolling(
            window=80, 
            min_periods=1
        ).std().reset_index(level=0, drop=True)
        
    df.fillna(method='ffill', inplace=True)
    df.fillna(0, inplace=True)
    return df

test_df = feature_engineering(test_df)
train_df = feature_engineering(train_df)

test_df.head(), train_df.head()
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['magnitude'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(method='ffill', inplace=True)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0, inplace=True)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['magnitude'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{col}_std'] = df.groupby('user')[col].rolling(
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:12: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(method='ffill', inplace=True)
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\1676528177.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0, inplace=True)
# (   user activity            time         x          y         z  magnitude  \
#  0    33  Jogging  49105962326000 -0.694638  12.680544  0.503953  12.709551
#  1    33  Jogging  49106062271000  5.012288  11.264028  0.953424  12.365693
#  2    33  Jogging  49106112167000  4.903325  10.882658 -0.081722  11.936562
#  3    33  Jogging  49106222305000 -0.612916  18.496431  3.023717  18.751973
#  4    33  Jogging  49106332290000 -1.184970  12.108489  7.205164  14.139804
#
#        x_std     y_std     z_std  magnitude_std
#  0  0.000000  0.000000  0.000000       0.000000
#  1  4.035406  1.001628  0.317824       0.243144
#  2  3.263895  0.947308  0.519065       0.387277
#  3  3.240326  3.529472  1.350791       3.222902
#  4  3.178345  3.105116  2.970432       2.792531  ,
#        user activity            time         x          y         z  magnitude  \
#  8489    17  Walking  57869902574000  0.572055   9.806650 -0.531194   9.837672
#  8490    17  Walking  57870012316000 -0.000000  10.188020 -0.572055  10.204068
#  8491    17  Walking  57870122301000 -0.231546   9.847511 -0.694638   9.874695
#  8492    17  Walking  57870222246000  0.149824  10.079058 -0.503953  10.092761
#  8493    17  Walking  57870332292000  0.149824  10.147159 -0.612916  10.166757
#
#           x_std     y_std     z_std  magnitude_std
#  8489  0.000000  0.000000  0.000000       0.000000
#  8490  0.404504  0.269669  0.028893       0.259081
#  8491  0.413649  0.209388  0.085059       0.201702
#  8492  0.338231  0.183201  0.084237       0.175384
#  8493  0.293170  0.175327  0.074850       0.168757  )

# %%
corr_df = train_df.copy()

# 시각화용 LabelEncoder 생성 및 적용
le_corr = LabelEncoder()
corr_df['activity'] = le_corr.fit_transform(corr_df['activity'])

# 상관관계 분석할 특성 선택 (activity 포함)
features_for_corr = ['activity', 'x', 'y', 'z', 'magnitude', 'x_std', 'y_std', 'z_std', 'magnitude_std']
corr_matrix = corr_df[features_for_corr].corr()

# 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='viridis', fmt='.2f', linewidths=.5)
plt.title('Feature Correlation Matrix with Activity', fontsize=15)
plt.show()

# %%
label_encoder = LabelEncoder()

train_df['activity'] = label_encoder.fit_transform(train_df['activity'])
test_df['activity'] = label_encoder.transform(test_df['activity'])
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\4128002732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['activity'] = label_encoder.fit_transform(train_df['activity'])
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\4128002732.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['activity'] = label_encoder.transform(test_df['activity'])

# %%
feature_columns_to_scale = ['x', 'y', 'z', 'magnitude', 'x_std', 'y_std', 'z_std', 'magnitude_std']

scaler = StandardScaler()
train_df[feature_columns_to_scale] = scaler.fit_transform(train_df[feature_columns_to_scale])

test_df[feature_columns_to_scale] = scaler.transform(test_df[feature_columns_to_scale])
# Out:
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\218149100.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[feature_columns_to_scale] = scaler.fit_transform(train_df[feature_columns_to_scale])
# C:\Users\c\AppData\Local\Temp\ipykernel_21900\218149100.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[feature_columns_to_scale] = scaler.transform(test_df[feature_columns_to_scale])

# %%
# hop_size를 frame_size 보다 작게 설정하여 중복하여 고려할 수 있게 함 (오버래핑)
Fs = 20
frame_size = Fs*4 # 80
hop_size = Fs*2 # 40
col = ['x_std', 'y_std', 'z_std', 'magnitude_std', 'activity']
feature_cols = ['x_std', 'y_std', 'z_std', 'magnitude_std']
label_col = 'activity'

# %%
def get_frames(df, frame_size, hop_size):
  """
  시계열 데이터를 CNN이 이해할 수 있게 재구성함.
  x,y,z 값을 각각의 채널로 나누고
  연속적인 데이터를 독립적인 여러개의 데이터로 나눔 (슬라이딩 윈도우 분할).
  이는 고정된 길이의 입력만 받을 수 있는 CNN 특성에서 기인함.

  Args:
    df: 데이터 프레임
    frame_size: 슬라이딩 윈도우 분할 사이즈
    hop_size: 슬라이딩 윈도우 사이즈

  Returns:
    frames: 분할된 데이터
    labels: 분할된 데이터의 레이블
  """
  N_FEATURES = 8
  
  # 사용할 피처 컬럼 목록 정의
  feature_columns = col

  frames = []
  labels = []
  for i in range(0, len(df) - frame_size, hop_size):
      frame = df[feature_cols].values[i: i + frame_size]
      label = df[label_col][i: i + frame_size].mode()[0]
      
      frames.append(frame)
      labels.append(label)

  # NumPy 배열로 변환
  frames = np.asarray(frames)
  labels = np.asarray(labels).astype(int)

  return frames, labels

# %%
class EarlyStopping:
    """검증 손실이 개선되지 않으면 학습을 조기에 중단시킵니다."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): 검증 손실이 개선된 후 기다리는 에폭 수
            verbose (bool): True일 경우 각 개선 사항에 대한 메시지를 출력
            delta (float): 개선으로 인정받기 위한 최소한의 변화량
            path (str): 가장 좋은 모델을 저장할 경로
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Validation loss가 감소하면 모델을 저장합니다."""
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# ## CNN + LSTM

# %%
class CNN_LSTM_Classifier(nn.Module):
    def __init__(self, input_size, cnn_out_channels, hidden_size, num_layers, num_classes, dropout=0.5):
        """
        input_size (int): 입력 데이터의 피처 수
        cnn_out_channels (int): CNN 레이어의 출력 채널 수
        lstm_hidden_size (int): LSTM의 은닉 상태 크기
        num_layers (int): LSTM 레이어의 수
        num_classes (int): 최종 분류할 클래스 수
        dropout (float): 드롭아웃 비율
        """
        super(CNN_LSTM_Classifier, self).__init__()

        # 1. 1D CNN 레이어
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=input_size, out_channels=cnn_out_channels, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )

        # 2. LSTM 레이어
        # CNN의 출력 채널 수가 LSTM의 입력 피처 수가 됨
        self.lstm = nn.LSTM(input_size=cnn_out_channels,
                              hidden_size=hidden_size,
                              num_layers=num_layers,
                              batch_first=True,
                              dropout=dropout if num_layers > 1 else 0)

        # 3. 최종 분류를 위한 Fully Connected 레이어
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        """
        모델의 순전파 과정
        x의 shape: (배치 크기, 시퀀스 길이, input_size)
        """
        # --- CNN 처리 ---
        # Conv1d는 (배치, 채널, 길이) 형태의 입력을 기대하므로 차원 변경
        x = x.permute(0, 2, 1)  # (배치, input_size, 시퀀스 길이)
        x = self.cnn(x)

        # --- LSTM 처리 ---
        # LSTM은 (배치, 시퀀스, 피처) 형태의 입력을 기대하므로 다시 차원 변경
        x = x.permute(0, 2, 1)  # (배치, 축소된 시퀀스 길이, cnn_out_channels)

        # LSTM 순전파 (hidden/cell state는 초기화)
        out, _ = self.lstm(x)

        # --- 최종 분류 ---
        # LSTM의 마지막 시점(time-step)의 출력만 사용
        final_hidden_state = out[:, -1, :]

        # 드롭아웃 적용 후 FC 레이어 통과
        out = self.dropout(final_hidden_state)
        out = self.fc(out)

        return out

# %%
model = CNN_LSTM_Classifier(input_size=4, cnn_out_channels=64, hidden_size=100, num_layers=2, num_classes=6)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# CNN1D(
#   (features): Sequential(
#     (0): Conv1d(3, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): LazyLinear(in_features=0, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): LazyLinear(in_features=0, out_features=6, bias=True)
#   )
# )

# %%
# --- 교차 검증 설정 ---
n_splits = 5  # 5-Fold Cross Validation
groups = train_df['user']
gkf = GroupKFold(n_splits=n_splits)

# 각 Fold의 훈련 기록을 저장할 리스트
fold_histories = []

best_val_loss = float('inf')
best_model_path = ''

stopped_epochs = []

# --- 교차 검증 루프 시작 ---
for fold, (train_idx, val_idx) in enumerate(gkf.split(train_df, train_df['activity'], groups)):
    print(f"===================== FOLD {fold+1}/{n_splits} =====================")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # --- 1. 데이터 전처리 (매 Fold마다 새로 수행) ---
    fold_train = train_df[col].iloc[train_idx]
    fold_val = train_df[col].iloc[val_idx]

    X_train, y_train = get_frames(fold_train, frame_size, hop_size)
    X_val, y_val = get_frames(fold_val, frame_size, hop_size)

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)

    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.long)

    # --- 2. 모델 및 학습 요소 초기화 (매 Fold마다 새로 수행) ---

    model = CNN_LSTM_Classifier(input_size=4, cnn_out_channels=64, hidden_size=100, num_layers=2, num_classes=6)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00001, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)
    

    # --- 3. DataLoader 및 EarlyStopping 초기화 ---
    batch_size = 64
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    epochs = 100 # 최대 에폭을 충분히 길게 설정
    patience = 5  # 5 에폭 동안 개선이 없으면 중단
    early_stopping = EarlyStopping(patience=patience, verbose=True, path=f'checkpoint_fold_{fold+1}.pt')

    # --- 4. 훈련 루프 ---
    history = {'train_loss': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        history['train_loss'].append(train_loss)

        # --- 5. 검증 루프 및 조기 종료 호출 ---
        model.eval()
        running_test_loss = 0.0
        all_predictions = []
        all_labels = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_test_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                all_predictions.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        test_loss = running_test_loss / len(val_loader.dataset)
        test_accuracy = accuracy_score(all_labels, all_predictions)
        history['val_loss'].append(test_loss)
        history['val_acc'].append(test_accuracy)

        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Val Loss: {test_loss:.4f}, Val Acc: {test_accuracy*100:.2f}%")

        scheduler.step(test_loss)

        # EarlyStopping 호출
        early_stopping(test_loss, model)
        if early_stopping.early_stop:
            stopped_epochs.append(epoch - patience + 1)
            print(f"Fold {fold+1} stopped at epoch {epoch - patience + 1}")
            break
        if not early_stopping.early_stop:
            stopped_epochs.append(epochs)
            print(f"Fold {fold+1} finished all {epochs} epochs.")

    # 가장 성능이 좋았던 모델의 기록을 저장
    best_acc = max(history['val_acc'])
    fold_histories.append({'fold': fold+1, 'best_accuracy': best_acc, 'history': history})

    if early_stopping.val_loss_min < best_val_loss:
        print(f"✨ New best model found in Fold {fold+1} with Val Loss: {early_stopping.val_loss_min:.6f}")
        best_val_loss = early_stopping.val_loss_min
        best_model_path = early_stopping.path
    


# --- 6. 최종 결과 분석 ---
print("\n===================== Final Results =====================")
all_accuracies = [h['best_accuracy'] for h in fold_histories]
for i, acc in enumerate(all_accuracies):
    print(f"Fold {i+1} Best Accuracy: {acc*100:.2f}%")

print(f"\nAverage Accuracy: {np.mean(all_accuracies)*100:.2f}%")
print(f"Standard Deviation: {np.std(all_accuracies)*100:.2f}%")
# Out:
# ===================== FOLD 1/5 =====================
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.7654, Val Loss: 1.7625, Val Acc: 13.06%
# Validation loss decreased (inf --> 1.762496).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [2/100], Train Loss: 1.7454, Val Loss: 1.7434, Val Acc: 56.31%
# Validation loss decreased (1.762496 --> 1.743357).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [3/100], Train Loss: 1.7219, Val Loss: 1.7215, Val Acc: 72.75%
# Validation loss decreased (1.743357 --> 1.721528).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [4/100], Train Loss: 1.6944, Val Loss: 1.6948, Val Acc: 73.31%
# Validation loss decreased (1.721528 --> 1.694772).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [5/100], Train Loss: 1.6614, Val Loss: 1.6591, Val Acc: 73.42%
# Validation loss decreased (1.694772 --> 1.659084).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [6/100], Train Loss: 1.6153, Val Loss: 1.6072, Val Acc: 73.20%
# Validation loss decreased (1.659084 --> 1.607248).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [7/100], Train Loss: 1.5458, Val Loss: 1.5232, Val Acc: 72.97%
# Validation loss decreased (1.607248 --> 1.523173).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [8/100], Train Loss: 1.4375, Val Loss: 1.3837, Val Acc: 72.41%
# Validation loss decreased (1.523173 --> 1.383690).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [9/100], Train Loss: 1.2800, Val Loss: 1.2128, Val Acc: 71.96%
# Validation loss decreased (1.383690 --> 1.212811).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [10/100], Train Loss: 1.1273, Val Loss: 1.0923, Val Acc: 71.96%
# Validation loss decreased (1.212811 --> 1.092299).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [11/100], Train Loss: 1.0090, Val Loss: 1.0035, Val Acc: 72.52%
# Validation loss decreased (1.092299 --> 1.003505).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [12/100], Train Loss: 0.9077, Val Loss: 0.9291, Val Acc: 73.09%
# Validation loss decreased (1.003505 --> 0.929066).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [13/100], Train Loss: 0.8242, Val Loss: 0.8781, Val Acc: 73.20%
# Validation loss decreased (0.929066 --> 0.878133).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [14/100], Train Loss: 0.7673, Val Loss: 0.8475, Val Acc: 73.20%
# Validation loss decreased (0.878133 --> 0.847546).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [15/100], Train Loss: 0.7313, Val Loss: 0.8212, Val Acc: 73.20%
# Validation loss decreased (0.847546 --> 0.821200).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [16/100], Train Loss: 0.7004, Val Loss: 0.7924, Val Acc: 73.20%
# Validation loss decreased (0.821200 --> 0.792380).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [17/100], Train Loss: 0.6744, Val Loss: 0.7719, Val Acc: 73.20%
# Validation loss decreased (0.792380 --> 0.771877).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [18/100], Train Loss: 0.6526, Val Loss: 0.7332, Val Acc: 73.20%
# Validation loss decreased (0.771877 --> 0.733174).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [19/100], Train Loss: 0.6371, Val Loss: 0.7177, Val Acc: 73.20%
# Validation loss decreased (0.733174 --> 0.717661).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [20/100], Train Loss: 0.6186, Val Loss: 0.6978, Val Acc: 73.20%
# Validation loss decreased (0.717661 --> 0.697801).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [21/100], Train Loss: 0.6051, Val Loss: 0.6917, Val Acc: 73.20%
# Validation loss decreased (0.697801 --> 0.691655).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [22/100], Train Loss: 0.6019, Val Loss: 0.6733, Val Acc: 73.20%
# Validation loss decreased (0.691655 --> 0.673315).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [23/100], Train Loss: 0.5929, Val Loss: 0.6457, Val Acc: 73.20%
# Validation loss decreased (0.673315 --> 0.645674).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [24/100], Train Loss: 0.5812, Val Loss: 0.6345, Val Acc: 73.20%
# Validation loss decreased (0.645674 --> 0.634487).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [25/100], Train Loss: 0.5770, Val Loss: 0.6656, Val Acc: 73.20%
# EarlyStopping counter: 1 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [26/100], Train Loss: 0.5694, Val Loss: 0.6283, Val Acc: 73.20%
# Validation loss decreased (0.634487 --> 0.628293).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [27/100], Train Loss: 0.5695, Val Loss: 0.6341, Val Acc: 73.20%
# EarlyStopping counter: 1 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [28/100], Train Loss: 0.5561, Val Loss: 0.6285, Val Acc: 73.20%
# EarlyStopping counter: 2 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [29/100], Train Loss: 0.5574, Val Loss: 0.6298, Val Acc: 73.20%
# EarlyStopping counter: 3 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [30/100], Train Loss: 0.5460, Val Loss: 0.6072, Val Acc: 73.20%
# Validation loss decreased (0.628293 --> 0.607157).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [31/100], Train Loss: 0.5484, Val Loss: 0.5989, Val Acc: 73.20%
# Validation loss decreased (0.607157 --> 0.598887).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [32/100], Train Loss: 0.5385, Val Loss: 0.5975, Val Acc: 73.20%
# Validation loss decreased (0.598887 --> 0.597512).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [33/100], Train Loss: 0.5314, Val Loss: 0.5977, Val Acc: 73.20%
# EarlyStopping counter: 1 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [34/100], Train Loss: 0.5299, Val Loss: 0.5840, Val Acc: 73.20%
# Validation loss decreased (0.597512 --> 0.584047).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [35/100], Train Loss: 0.5238, Val Loss: 0.5815, Val Acc: 73.20%
# Validation loss decreased (0.584047 --> 0.581467).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [36/100], Train Loss: 0.5250, Val Loss: 0.5791, Val Acc: 73.20%
# Validation loss decreased (0.581467 --> 0.579081).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [37/100], Train Loss: 0.5167, Val Loss: 0.5744, Val Acc: 73.20%
# Validation loss decreased (0.579081 --> 0.574385).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [38/100], Train Loss: 0.5146, Val Loss: 0.5548, Val Acc: 73.20%
# Validation loss decreased (0.574385 --> 0.554778).  Saving model ...
# Fold 1 finished all 100 epochs.
# Epoch [39/100], Train Loss: 0.5102, Val Loss: 0.5725, Val Acc: 73.20%
# EarlyStopping counter: 1 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [40/100], Train Loss: 0.5017, Val Loss: 0.5654, Val Acc: 73.20%
# EarlyStopping counter: 2 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [41/100], Train Loss: 0.5023, Val Loss: 0.5734, Val Acc: 73.20%
# EarlyStopping counter: 3 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [42/100], Train Loss: 0.4908, Val Loss: 0.5704, Val Acc: 73.20%
# EarlyStopping counter: 4 out of 5
# Fold 1 finished all 100 epochs.
# Epoch [43/100], Train Loss: 0.4907, Val Loss: 0.5743, Val Acc: 73.31%
# EarlyStopping counter: 5 out of 5
# Fold 1 stopped at epoch 38
# ✨ New best model found in Fold 1 with Val Loss: 0.554778
# ===================== FOLD 2/5 =====================
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.7736, Val Loss: 1.7768, Val Acc: 37.84%
# Validation loss decreased (inf --> 1.776810).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [2/100], Train Loss: 1.7527, Val Loss: 1.7605, Val Acc: 34.63%
# Validation loss decreased (1.776810 --> 1.760509).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [3/100], Train Loss: 1.7293, Val Loss: 1.7418, Val Acc: 34.52%
# Validation loss decreased (1.760509 --> 1.741768).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [4/100], Train Loss: 1.7012, Val Loss: 1.7184, Val Acc: 34.52%
# Validation loss decreased (1.741768 --> 1.718364).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [5/100], Train Loss: 1.6657, Val Loss: 1.6870, Val Acc: 38.53%
# Validation loss decreased (1.718364 --> 1.686950).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [6/100], Train Loss: 1.6164, Val Loss: 1.6392, Val Acc: 60.67%
# Validation loss decreased (1.686950 --> 1.639219).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [7/100], Train Loss: 1.5434, Val Loss: 1.5624, Val Acc: 65.94%
# Validation loss decreased (1.639219 --> 1.562407).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [8/100], Train Loss: 1.4256, Val Loss: 1.4422, Val Acc: 67.43%
# Validation loss decreased (1.562407 --> 1.442194).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [9/100], Train Loss: 1.2676, Val Loss: 1.3154, Val Acc: 68.81%
# Validation loss decreased (1.442194 --> 1.315388).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [10/100], Train Loss: 1.1163, Val Loss: 1.2352, Val Acc: 69.72%
# Validation loss decreased (1.315388 --> 1.235156).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [11/100], Train Loss: 0.9906, Val Loss: 1.1839, Val Acc: 69.84%
# Validation loss decreased (1.235156 --> 1.183948).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [12/100], Train Loss: 0.8720, Val Loss: 1.1403, Val Acc: 69.84%
# Validation loss decreased (1.183948 --> 1.140319).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [13/100], Train Loss: 0.7725, Val Loss: 1.1210, Val Acc: 69.95%
# Validation loss decreased (1.140319 --> 1.120973).  Saving model ...
# Fold 2 finished all 100 epochs.
# Epoch [14/100], Train Loss: 0.7061, Val Loss: 1.1261, Val Acc: 69.95%
# EarlyStopping counter: 1 out of 5
# Fold 2 finished all 100 epochs.
# Epoch [15/100], Train Loss: 0.6717, Val Loss: 1.1334, Val Acc: 69.95%
# EarlyStopping counter: 2 out of 5
# Fold 2 finished all 100 epochs.
# Epoch [16/100], Train Loss: 0.6436, Val Loss: 1.1434, Val Acc: 69.95%
# EarlyStopping counter: 3 out of 5
# Fold 2 finished all 100 epochs.
# Epoch [17/100], Train Loss: 0.6268, Val Loss: 1.1530, Val Acc: 69.72%
# EarlyStopping counter: 4 out of 5
# Fold 2 finished all 100 epochs.
# Epoch [18/100], Train Loss: 0.6146, Val Loss: 1.1570, Val Acc: 69.72%
# EarlyStopping counter: 5 out of 5
# Fold 2 stopped at epoch 13
# ===================== FOLD 3/5 =====================
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.8482, Val Loss: 1.8398, Val Acc: 0.00%
# Validation loss decreased (inf --> 1.839834).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [2/100], Train Loss: 1.8296, Val Loss: 1.8221, Val Acc: 0.00%
# Validation loss decreased (1.839834 --> 1.822079).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [3/100], Train Loss: 1.8106, Val Loss: 1.8023, Val Acc: 28.77%
# Validation loss decreased (1.822079 --> 1.802302).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [4/100], Train Loss: 1.7882, Val Loss: 1.7787, Val Acc: 32.07%
# Validation loss decreased (1.802302 --> 1.778748).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [5/100], Train Loss: 1.7596, Val Loss: 1.7483, Val Acc: 37.56%
# Validation loss decreased (1.778748 --> 1.748287).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [6/100], Train Loss: 1.7211, Val Loss: 1.7052, Val Acc: 47.55%
# Validation loss decreased (1.748287 --> 1.705225).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [7/100], Train Loss: 1.6663, Val Loss: 1.6391, Val Acc: 51.55%
# Validation loss decreased (1.705225 --> 1.639141).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [8/100], Train Loss: 1.5815, Val Loss: 1.5319, Val Acc: 53.65%
# Validation loss decreased (1.639141 --> 1.531923).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [9/100], Train Loss: 1.4500, Val Loss: 1.3872, Val Acc: 55.64%
# Validation loss decreased (1.531923 --> 1.387165).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [10/100], Train Loss: 1.2983, Val Loss: 1.2591, Val Acc: 62.94%
# Validation loss decreased (1.387165 --> 1.259093).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [11/100], Train Loss: 1.1839, Val Loss: 1.1711, Val Acc: 72.43%
# Validation loss decreased (1.259093 --> 1.171135).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [12/100], Train Loss: 1.1059, Val Loss: 1.0952, Val Acc: 75.32%
# Validation loss decreased (1.171135 --> 1.095237).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [13/100], Train Loss: 1.0295, Val Loss: 1.0148, Val Acc: 76.52%
# Validation loss decreased (1.095237 --> 1.014770).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [14/100], Train Loss: 0.9444, Val Loss: 0.9334, Val Acc: 75.02%
# Validation loss decreased (1.014770 --> 0.933376).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [15/100], Train Loss: 0.8498, Val Loss: 0.8783, Val Acc: 72.63%
# Validation loss decreased (0.933376 --> 0.878335).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [16/100], Train Loss: 0.7946, Val Loss: 0.8547, Val Acc: 71.53%
# Validation loss decreased (0.878335 --> 0.854737).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [17/100], Train Loss: 0.7661, Val Loss: 0.8390, Val Acc: 71.33%
# Validation loss decreased (0.854737 --> 0.838967).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [18/100], Train Loss: 0.7346, Val Loss: 0.8263, Val Acc: 71.23%
# Validation loss decreased (0.838967 --> 0.826288).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [19/100], Train Loss: 0.7221, Val Loss: 0.8108, Val Acc: 71.13%
# Validation loss decreased (0.826288 --> 0.810819).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [20/100], Train Loss: 0.7028, Val Loss: 0.7957, Val Acc: 71.03%
# Validation loss decreased (0.810819 --> 0.795698).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [21/100], Train Loss: 0.6838, Val Loss: 0.7735, Val Acc: 71.03%
# Validation loss decreased (0.795698 --> 0.773507).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [22/100], Train Loss: 0.6721, Val Loss: 0.7511, Val Acc: 70.93%
# Validation loss decreased (0.773507 --> 0.751108).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [23/100], Train Loss: 0.6507, Val Loss: 0.7277, Val Acc: 70.83%
# Validation loss decreased (0.751108 --> 0.727735).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [24/100], Train Loss: 0.6315, Val Loss: 0.7099, Val Acc: 70.83%
# Validation loss decreased (0.727735 --> 0.709916).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [25/100], Train Loss: 0.6108, Val Loss: 0.6945, Val Acc: 70.83%
# Validation loss decreased (0.709916 --> 0.694482).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [26/100], Train Loss: 0.5971, Val Loss: 0.6909, Val Acc: 70.63%
# Validation loss decreased (0.694482 --> 0.690866).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [27/100], Train Loss: 0.5876, Val Loss: 0.6848, Val Acc: 70.63%
# Validation loss decreased (0.690866 --> 0.684780).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [28/100], Train Loss: 0.5719, Val Loss: 0.6869, Val Acc: 70.63%
# EarlyStopping counter: 1 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [29/100], Train Loss: 0.5645, Val Loss: 0.6865, Val Acc: 70.63%
# EarlyStopping counter: 2 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [30/100], Train Loss: 0.5577, Val Loss: 0.6894, Val Acc: 70.63%
# EarlyStopping counter: 3 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [31/100], Train Loss: 0.5521, Val Loss: 0.6809, Val Acc: 70.63%
# Validation loss decreased (0.684780 --> 0.680883).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [32/100], Train Loss: 0.5469, Val Loss: 0.6815, Val Acc: 70.63%
# EarlyStopping counter: 1 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [33/100], Train Loss: 0.5380, Val Loss: 0.6749, Val Acc: 70.73%
# Validation loss decreased (0.680883 --> 0.674940).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [34/100], Train Loss: 0.5296, Val Loss: 0.6825, Val Acc: 70.63%
# EarlyStopping counter: 1 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [35/100], Train Loss: 0.5234, Val Loss: 0.6724, Val Acc: 70.73%
# Validation loss decreased (0.674940 --> 0.672444).  Saving model ...
# Fold 3 finished all 100 epochs.
# Epoch [36/100], Train Loss: 0.5202, Val Loss: 0.6805, Val Acc: 73.83%
# EarlyStopping counter: 1 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [37/100], Train Loss: 0.5117, Val Loss: 0.6827, Val Acc: 78.32%
# EarlyStopping counter: 2 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [38/100], Train Loss: 0.5093, Val Loss: 0.6870, Val Acc: 79.72%
# EarlyStopping counter: 3 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [39/100], Train Loss: 0.5074, Val Loss: 0.6920, Val Acc: 79.12%
# EarlyStopping counter: 4 out of 5
# Fold 3 finished all 100 epochs.
# Epoch [40/100], Train Loss: 0.4992, Val Loss: 0.6882, Val Acc: 78.02%
# EarlyStopping counter: 5 out of 5
# Fold 3 stopped at epoch 35
# ===================== FOLD 4/5 =====================
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.8091, Val Loss: 1.8043, Val Acc: 6.76%
# Validation loss decreased (inf --> 1.804313).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [2/100], Train Loss: 1.7903, Val Loss: 1.7821, Val Acc: 6.76%
# Validation loss decreased (1.804313 --> 1.782072).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [3/100], Train Loss: 1.7699, Val Loss: 1.7575, Val Acc: 39.53%
# Validation loss decreased (1.782072 --> 1.757457).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [4/100], Train Loss: 1.7462, Val Loss: 1.7276, Val Acc: 40.32%
# Validation loss decreased (1.757457 --> 1.727564).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [5/100], Train Loss: 1.7165, Val Loss: 1.6881, Val Acc: 40.54%
# Validation loss decreased (1.727564 --> 1.688104).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [6/100], Train Loss: 1.6762, Val Loss: 1.6308, Val Acc: 49.89%
# Validation loss decreased (1.688104 --> 1.630792).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [7/100], Train Loss: 1.6117, Val Loss: 1.5417, Val Acc: 71.40%
# Validation loss decreased (1.630792 --> 1.541713).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [8/100], Train Loss: 1.5109, Val Loss: 1.4165, Val Acc: 68.69%
# Validation loss decreased (1.541713 --> 1.416524).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [9/100], Train Loss: 1.3796, Val Loss: 1.2947, Val Acc: 68.81%
# Validation loss decreased (1.416524 --> 1.294704).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [10/100], Train Loss: 1.2637, Val Loss: 1.2074, Val Acc: 72.97%
# Validation loss decreased (1.294704 --> 1.207398).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [11/100], Train Loss: 1.1815, Val Loss: 1.1412, Val Acc: 78.27%
# Validation loss decreased (1.207398 --> 1.141192).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [12/100], Train Loss: 1.1244, Val Loss: 1.0810, Val Acc: 82.77%
# Validation loss decreased (1.141192 --> 1.080972).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [13/100], Train Loss: 1.0705, Val Loss: 1.0090, Val Acc: 85.59%
# Validation loss decreased (1.080972 --> 1.009004).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [14/100], Train Loss: 1.0060, Val Loss: 0.9115, Val Acc: 86.04%
# Validation loss decreased (1.009004 --> 0.911466).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [15/100], Train Loss: 0.9265, Val Loss: 0.7883, Val Acc: 86.04%
# Validation loss decreased (0.911466 --> 0.788293).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [16/100], Train Loss: 0.8471, Val Loss: 0.6807, Val Acc: 86.04%
# Validation loss decreased (0.788293 --> 0.680742).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [17/100], Train Loss: 0.7812, Val Loss: 0.6162, Val Acc: 85.92%
# Validation loss decreased (0.680742 --> 0.616224).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [18/100], Train Loss: 0.7352, Val Loss: 0.5797, Val Acc: 85.92%
# Validation loss decreased (0.616224 --> 0.579666).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [19/100], Train Loss: 0.6876, Val Loss: 0.5613, Val Acc: 85.92%
# Validation loss decreased (0.579666 --> 0.561345).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [20/100], Train Loss: 0.6485, Val Loss: 0.5601, Val Acc: 85.92%
# Validation loss decreased (0.561345 --> 0.560140).  Saving model ...
# Fold 4 finished all 100 epochs.
# Epoch [21/100], Train Loss: 0.6179, Val Loss: 0.5722, Val Acc: 85.92%
# EarlyStopping counter: 1 out of 5
# Fold 4 finished all 100 epochs.
# Epoch [22/100], Train Loss: 0.5957, Val Loss: 0.5855, Val Acc: 85.81%
# EarlyStopping counter: 2 out of 5
# Fold 4 finished all 100 epochs.
# Epoch [23/100], Train Loss: 0.5772, Val Loss: 0.6003, Val Acc: 85.81%
# EarlyStopping counter: 3 out of 5
# Fold 4 finished all 100 epochs.
# Epoch [24/100], Train Loss: 0.5719, Val Loss: 0.6040, Val Acc: 85.81%
# EarlyStopping counter: 4 out of 5
# Fold 4 finished all 100 epochs.
# Epoch [25/100], Train Loss: 0.5652, Val Loss: 0.6061, Val Acc: 85.70%
# EarlyStopping counter: 5 out of 5
# Fold 4 stopped at epoch 20
# ===================== FOLD 5/5 =====================
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100], Train Loss: 1.8135, Val Loss: 1.8074, Val Acc: 0.00%
# Validation loss decreased (inf --> 1.807370).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [2/100], Train Loss: 1.7961, Val Loss: 1.7873, Val Acc: 2.09%
# Validation loss decreased (1.807370 --> 1.787307).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [3/100], Train Loss: 1.7770, Val Loss: 1.7655, Val Acc: 37.76%
# Validation loss decreased (1.787307 --> 1.765479).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [4/100], Train Loss: 1.7567, Val Loss: 1.7402, Val Acc: 43.83%
# Validation loss decreased (1.765479 --> 1.740238).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [5/100], Train Loss: 1.7323, Val Loss: 1.7091, Val Acc: 46.50%
# Validation loss decreased (1.740238 --> 1.709106).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [6/100], Train Loss: 1.7020, Val Loss: 1.6679, Val Acc: 65.49%
# Validation loss decreased (1.709106 --> 1.667882).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [7/100], Train Loss: 1.6584, Val Loss: 1.6076, Val Acc: 69.82%
# Validation loss decreased (1.667882 --> 1.607593).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [8/100], Train Loss: 1.5964, Val Loss: 1.5179, Val Acc: 72.49%
# Validation loss decreased (1.607593 --> 1.517858).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [9/100], Train Loss: 1.5078, Val Loss: 1.3899, Val Acc: 74.51%
# Validation loss decreased (1.517858 --> 1.389900).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [10/100], Train Loss: 1.4049, Val Loss: 1.2563, Val Acc: 77.55%
# Validation loss decreased (1.389900 --> 1.256345).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [11/100], Train Loss: 1.3143, Val Loss: 1.1514, Val Acc: 80.94%
# Validation loss decreased (1.256345 --> 1.151419).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [12/100], Train Loss: 1.2518, Val Loss: 1.0768, Val Acc: 84.33%
# Validation loss decreased (1.151419 --> 1.076795).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [13/100], Train Loss: 1.2050, Val Loss: 1.0216, Val Acc: 86.06%
# Validation loss decreased (1.076795 --> 1.021620).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [14/100], Train Loss: 1.1698, Val Loss: 0.9782, Val Acc: 86.86%
# Validation loss decreased (1.021620 --> 0.978167).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [15/100], Train Loss: 1.1390, Val Loss: 0.9363, Val Acc: 87.08%
# Validation loss decreased (0.978167 --> 0.936308).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [16/100], Train Loss: 1.1007, Val Loss: 0.8921, Val Acc: 87.15%
# Validation loss decreased (0.936308 --> 0.892095).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [17/100], Train Loss: 1.0620, Val Loss: 0.8382, Val Acc: 87.22%
# Validation loss decreased (0.892095 --> 0.838159).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [18/100], Train Loss: 1.0122, Val Loss: 0.7670, Val Acc: 87.22%
# Validation loss decreased (0.838159 --> 0.766967).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [19/100], Train Loss: 0.9526, Val Loss: 0.6827, Val Acc: 87.15%
# Validation loss decreased (0.766967 --> 0.682663).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [20/100], Train Loss: 0.8891, Val Loss: 0.6022, Val Acc: 86.86%
# Validation loss decreased (0.682663 --> 0.602231).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [21/100], Train Loss: 0.8440, Val Loss: 0.5484, Val Acc: 86.79%
# Validation loss decreased (0.602231 --> 0.548420).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [22/100], Train Loss: 0.8076, Val Loss: 0.5105, Val Acc: 86.79%
# Validation loss decreased (0.548420 --> 0.510495).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [23/100], Train Loss: 0.7789, Val Loss: 0.4803, Val Acc: 86.86%
# Validation loss decreased (0.510495 --> 0.480260).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [24/100], Train Loss: 0.7458, Val Loss: 0.4502, Val Acc: 86.86%
# Validation loss decreased (0.480260 --> 0.450247).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [25/100], Train Loss: 0.7238, Val Loss: 0.4231, Val Acc: 86.86%
# Validation loss decreased (0.450247 --> 0.423051).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [26/100], Train Loss: 0.7038, Val Loss: 0.3995, Val Acc: 86.86%
# Validation loss decreased (0.423051 --> 0.399492).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [27/100], Train Loss: 0.6752, Val Loss: 0.3826, Val Acc: 86.79%
# Validation loss decreased (0.399492 --> 0.382580).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [28/100], Train Loss: 0.6634, Val Loss: 0.3703, Val Acc: 86.79%
# Validation loss decreased (0.382580 --> 0.370269).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [29/100], Train Loss: 0.6562, Val Loss: 0.3671, Val Acc: 86.71%
# Validation loss decreased (0.370269 --> 0.367062).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [30/100], Train Loss: 0.6465, Val Loss: 0.3615, Val Acc: 86.79%
# Validation loss decreased (0.367062 --> 0.361474).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [31/100], Train Loss: 0.6411, Val Loss: 0.3585, Val Acc: 86.79%
# Validation loss decreased (0.361474 --> 0.358465).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [32/100], Train Loss: 0.6332, Val Loss: 0.3562, Val Acc: 86.79%
# Validation loss decreased (0.358465 --> 0.356202).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [33/100], Train Loss: 0.6309, Val Loss: 0.3570, Val Acc: 86.79%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [34/100], Train Loss: 0.6171, Val Loss: 0.3517, Val Acc: 86.79%
# Validation loss decreased (0.356202 --> 0.351737).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [35/100], Train Loss: 0.6169, Val Loss: 0.3469, Val Acc: 86.79%
# Validation loss decreased (0.351737 --> 0.346925).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [36/100], Train Loss: 0.6078, Val Loss: 0.3476, Val Acc: 86.93%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [37/100], Train Loss: 0.6043, Val Loss: 0.3427, Val Acc: 86.93%
# Validation loss decreased (0.346925 --> 0.342710).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [38/100], Train Loss: 0.5987, Val Loss: 0.3440, Val Acc: 86.93%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [39/100], Train Loss: 0.5934, Val Loss: 0.3422, Val Acc: 87.00%
# Validation loss decreased (0.342710 --> 0.342190).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [40/100], Train Loss: 0.5893, Val Loss: 0.3386, Val Acc: 87.15%
# Validation loss decreased (0.342190 --> 0.338615).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [41/100], Train Loss: 0.5833, Val Loss: 0.3403, Val Acc: 87.22%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [42/100], Train Loss: 0.5797, Val Loss: 0.3361, Val Acc: 87.58%
# Validation loss decreased (0.338615 --> 0.336079).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [43/100], Train Loss: 0.5684, Val Loss: 0.3354, Val Acc: 87.80%
# Validation loss decreased (0.336079 --> 0.335378).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [44/100], Train Loss: 0.5704, Val Loss: 0.3334, Val Acc: 88.01%
# Validation loss decreased (0.335378 --> 0.333365).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [45/100], Train Loss: 0.5616, Val Loss: 0.3350, Val Acc: 87.94%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [46/100], Train Loss: 0.5619, Val Loss: 0.3335, Val Acc: 87.51%
# EarlyStopping counter: 2 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [47/100], Train Loss: 0.5599, Val Loss: 0.3312, Val Acc: 87.29%
# Validation loss decreased (0.333365 --> 0.331214).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [48/100], Train Loss: 0.5527, Val Loss: 0.3301, Val Acc: 87.73%
# Validation loss decreased (0.331214 --> 0.330087).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [49/100], Train Loss: 0.5430, Val Loss: 0.3324, Val Acc: 87.94%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [50/100], Train Loss: 0.5401, Val Loss: 0.3317, Val Acc: 88.16%
# EarlyStopping counter: 2 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [51/100], Train Loss: 0.5356, Val Loss: 0.3255, Val Acc: 88.59%
# Validation loss decreased (0.330087 --> 0.325498).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [52/100], Train Loss: 0.5380, Val Loss: 0.3251, Val Acc: 88.66%
# Validation loss decreased (0.325498 --> 0.325115).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [53/100], Train Loss: 0.5286, Val Loss: 0.3263, Val Acc: 88.81%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [54/100], Train Loss: 0.5259, Val Loss: 0.3258, Val Acc: 89.03%
# EarlyStopping counter: 2 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [55/100], Train Loss: 0.5210, Val Loss: 0.3258, Val Acc: 88.95%
# EarlyStopping counter: 3 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [56/100], Train Loss: 0.5161, Val Loss: 0.3235, Val Acc: 88.95%
# Validation loss decreased (0.325115 --> 0.323486).  Saving model ...
# Fold 5 finished all 100 epochs.
# Epoch [57/100], Train Loss: 0.5175, Val Loss: 0.3240, Val Acc: 88.95%
# EarlyStopping counter: 1 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [58/100], Train Loss: 0.5090, Val Loss: 0.3254, Val Acc: 88.88%
# EarlyStopping counter: 2 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [59/100], Train Loss: 0.5083, Val Loss: 0.3265, Val Acc: 88.95%
# EarlyStopping counter: 3 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [60/100], Train Loss: 0.5069, Val Loss: 0.3237, Val Acc: 89.31%
# EarlyStopping counter: 4 out of 5
# Fold 5 finished all 100 epochs.
# Epoch [61/100], Train Loss: 0.4953, Val Loss: 0.3246, Val Acc: 89.39%
# EarlyStopping counter: 5 out of 5
# Fold 5 stopped at epoch 56
# ✨ New best model found in Fold 5 with Val Loss: 0.323486
#
# ===================== Final Results =====================
# Fold 1 Best Accuracy: 73.42%
# Fold 2 Best Accuracy: 69.95%
# Fold 3 Best Accuracy: 79.72%
# Fold 4 Best Accuracy: 86.04%
# Fold 5 Best Accuracy: 89.39%
#
# Average Accuracy: 79.70%
# Standard Deviation: 7.33%

# %%
import matplotlib.pyplot as plt

for hist in fold_histories:
    fold = hist['fold']
    epochs = len(hist['history']['train_loss']) # Assuming train_loss, val_loss, and val_acc have the same length
    epoch_range = range(1, epochs + 1)

    # Create a figure and a set of subplots for each fold
    fig, axes = plt.subplots(2, 1, figsize=(8, 8))
    fig.suptitle(f'Training History for Fold {fold}', fontsize=16)

    # Plot Training and Validation Loss
    axes[0].plot(epoch_range, hist['history']['train_loss'], label='Train Loss')
    axes[0].plot(epoch_range, hist['history']['val_loss'], label='Validation Loss')
    axes[0].set_ylabel('Loss')
    axes[0].set_title('Loss')
    axes[0].legend()
    axes[0].grid(True)

    # Plot Validation Accuracy
    axes[1].plot(epoch_range, hist['history']['val_acc'], label='Validation Accuracy', color='green')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_title('Accuracy')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent suptitle overlap
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- 1. 데이터 준비 (Fold별 길이가 달라도 처리 가능하도록) ---
# 이전 코드에서 fold_histories 리스트에 결과가 저장되어 있다고 가정

# 각 Fold의 history 리스트 추출
train_losses_folds = [h['history']['train_loss'] for h in fold_histories]
test_losses_folds = [h['history']['val_loss'] for h in fold_histories]
test_acc_folds = [h['history']['val_acc'] for h in fold_histories]

# 가장 길게 학습한 에폭 수 찾기
max_epochs = max([len(h) for h in train_losses_folds])

# NumPy 배열로 변환 (길이가 짧은 Fold는 NaN으로 채움)
def pad_history(histories, max_len):
    padded = np.full((len(histories), max_len), np.nan)
    for i, h in enumerate(histories):
        padded[i, :len(h)] = h
    return padded

all_train_losses = pad_history(train_losses_folds, max_epochs)
all_test_losses = pad_history(test_losses_folds, max_epochs)
all_test_accs = pad_history(test_acc_folds, max_epochs)

# --- 2. 평균 및 표준편차 계산 ---
mean_train_loss = np.nanmean(all_train_losses, axis=0)
std_train_loss = np.nanstd(all_train_losses, axis=0)

mean_test_loss = np.nanmean(all_test_losses, axis=0)
std_test_loss = np.nanstd(all_test_losses, axis=0)

mean_test_acc = np.nanmean(all_test_accs, axis=0)
std_test_acc = np.nanstd(all_test_accs, axis=0)

# --- 3. 그래프 그리기 ---
epoch_range = range(1, max_epochs + 1)

# 정확도(Accuracy) 그래프
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epoch_range, mean_test_acc, 'b-', label='Average Validation Accuracy')
plt.fill_between(epoch_range,
                 mean_test_acc - std_test_acc,
                 mean_test_acc + std_test_acc,
                 color='blue', alpha=0.2, label='Standard Deviation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# 손실(Loss) 그래프
plt.subplot(1, 2, 2)
plt.plot(epoch_range, mean_train_loss, 'g-', label='Average Train Loss')
plt.plot(epoch_range, mean_test_loss, 'r-', label='Average Validation Loss')
plt.fill_between(epoch_range,
                 mean_test_loss - std_test_loss,
                 mean_test_loss + std_test_loss,
                 color='red', alpha=0.2, label='Validation Loss Std Dev')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# --- 💡 새로운 부분: 전체 훈련 데이터로 재학습 ---
print(f"\n===================== Retraining on Full Training Data =====================")
# 1. CV에서 찾은 최적의 에포크 수를 평균내어 결정 (소수점 버림)
optimal_epochs = int(np.mean(stopped_epochs))
print(f"Optimal epochs determined from CV: {optimal_epochs}")

# 2. 전체 훈련 데이터를 위한 DataLoader 생성
X_train_full, y_train_full = get_frames(train_df, frame_size, hop_size)
X_train_full_tensor = torch.tensor(X_train_full, dtype=torch.float32)
y_train_full_tensor = torch.tensor(y_train_full, dtype=torch.long)

full_train_dataset = TensorDataset(X_train_full_tensor, y_train_full_tensor)
full_train_loader = DataLoader(full_train_dataset, batch_size=batch_size, shuffle=True)

# 3. 최종 모델을 위한 새로운 모델 객체 생성 및 초기화
final_model = CNN_LSTM_Classifier(input_size=4, cnn_out_channels=64, hidden_size=100, num_layers=2, num_classes=6).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(final_model.parameters(), lr=0.00001, weight_decay=1e-4)

# 4. 전체 훈련 데이터로 `optimal_epochs` 만큼 학습
for epoch in range(optimal_epochs):
    final_model.train()
    running_loss = 0.0
    for inputs, labels in full_train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = final_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(full_train_loader.dataset)
    print(f"Retraining Epoch [{epoch+1}/{optimal_epochs}], Loss: {epoch_loss:.4f}")

print("Retraining finished.")
# Out:
# ===================== Retraining on Full Training Data =====================
# Optimal epochs determined from CV: 98
# Retraining Epoch [1/98], Loss: 1.7649
# Retraining Epoch [2/98], Loss: 1.7410
# Retraining Epoch [3/98], Loss: 1.7111
# Retraining Epoch [4/98], Loss: 1.6710
# Retraining Epoch [5/98], Loss: 1.6059
# Retraining Epoch [6/98], Loss: 1.4970
# Retraining Epoch [7/98], Loss: 1.3271
# Retraining Epoch [8/98], Loss: 1.1678
# Retraining Epoch [9/98], Loss: 1.0468
# Retraining Epoch [10/98], Loss: 0.9255
# Retraining Epoch [11/98], Loss: 0.8264
# Retraining Epoch [12/98], Loss: 0.7556
# Retraining Epoch [13/98], Loss: 0.7066
# Retraining Epoch [14/98], Loss: 0.6637
# Retraining Epoch [15/98], Loss: 0.6285
# Retraining Epoch [16/98], Loss: 0.6053
# Retraining Epoch [17/98], Loss: 0.5893
# Retraining Epoch [18/98], Loss: 0.5797
# Retraining Epoch [19/98], Loss: 0.5704
# Retraining Epoch [20/98], Loss: 0.5608
# Retraining Epoch [21/98], Loss: 0.5503
# Retraining Epoch [22/98], Loss: 0.5465
# Retraining Epoch [23/98], Loss: 0.5369
# Retraining Epoch [24/98], Loss: 0.5332
# Retraining Epoch [25/98], Loss: 0.5265
# Retraining Epoch [26/98], Loss: 0.5247
# Retraining Epoch [27/98], Loss: 0.5131
# Retraining Epoch [28/98], Loss: 0.5128
# Retraining Epoch [29/98], Loss: 0.5063
# Retraining Epoch [30/98], Loss: 0.5031
# Retraining Epoch [31/98], Loss: 0.4964
# Retraining Epoch [32/98], Loss: 0.4928
# Retraining Epoch [33/98], Loss: 0.4889
# Retraining Epoch [34/98], Loss: 0.4843
# Retraining Epoch [35/98], Loss: 0.4811
# Retraining Epoch [36/98], Loss: 0.4771
# Retraining Epoch [37/98], Loss: 0.4742
# Retraining Epoch [38/98], Loss: 0.4714
# Retraining Epoch [39/98], Loss: 0.4665
# Retraining Epoch [40/98], Loss: 0.4628
# Retraining Epoch [41/98], Loss: 0.4634
# Retraining Epoch [42/98], Loss: 0.4564
# Retraining Epoch [43/98], Loss: 0.4527
# Retraining Epoch [44/98], Loss: 0.4485
# Retraining Epoch [45/98], Loss: 0.4488
# Retraining Epoch [46/98], Loss: 0.4441
# Retraining Epoch [47/98], Loss: 0.4434
# Retraining Epoch [48/98], Loss: 0.4407
# Retraining Epoch [49/98], Loss: 0.4372
# Retraining Epoch [50/98], Loss: 0.4375
# Retraining Epoch [51/98], Loss: 0.4341
# Retraining Epoch [52/98], Loss: 0.4339
# Retraining Epoch [53/98], Loss: 0.4306
# Retraining Epoch [54/98], Loss: 0.4262
# Retraining Epoch [55/98], Loss: 0.4241
# Retraining Epoch [56/98], Loss: 0.4227
# Retraining Epoch [57/98], Loss: 0.4223
# Retraining Epoch [58/98], Loss: 0.4226
# Retraining Epoch [59/98], Loss: 0.4193
# Retraining Epoch [60/98], Loss: 0.4241
# Retraining Epoch [61/98], Loss: 0.4166
# Retraining Epoch [62/98], Loss: 0.4145
# Retraining Epoch [63/98], Loss: 0.4114
# Retraining Epoch [64/98], Loss: 0.4107
# Retraining Epoch [65/98], Loss: 0.4112
# Retraining Epoch [66/98], Loss: 0.4099
# Retraining Epoch [67/98], Loss: 0.4026
# Retraining Epoch [68/98], Loss: 0.4038
# Retraining Epoch [69/98], Loss: 0.4027
# Retraining Epoch [70/98], Loss: 0.3982
# Retraining Epoch [71/98], Loss: 0.4018
# Retraining Epoch [72/98], Loss: 0.3983
# Retraining Epoch [73/98], Loss: 0.3973
# Retraining Epoch [74/98], Loss: 0.3948
# Retraining Epoch [75/98], Loss: 0.3960
# Retraining Epoch [76/98], Loss: 0.3897
# Retraining Epoch [77/98], Loss: 0.3906
# Retraining Epoch [78/98], Loss: 0.3890
# Retraining Epoch [79/98], Loss: 0.3885
# Retraining Epoch [80/98], Loss: 0.3887
# Retraining Epoch [81/98], Loss: 0.3857
# Retraining Epoch [82/98], Loss: 0.3878
# Retraining Epoch [83/98], Loss: 0.3819
# Retraining Epoch [84/98], Loss: 0.3830
# Retraining Epoch [85/98], Loss: 0.3784
# Retraining Epoch [86/98], Loss: 0.3783
# Retraining Epoch [87/98], Loss: 0.3744
# Retraining Epoch [88/98], Loss: 0.3795
# Retraining Epoch [89/98], Loss: 0.3737
# Retraining Epoch [90/98], Loss: 0.3700
# Retraining Epoch [91/98], Loss: 0.3723
# Retraining Epoch [92/98], Loss: 0.3702
# Retraining Epoch [93/98], Loss: 0.3699
# Retraining Epoch [94/98], Loss: 0.3716
# Retraining Epoch [95/98], Loss: 0.3635
# Retraining Epoch [96/98], Loss: 0.3651
# Retraining Epoch [97/98], Loss: 0.3679
# Retraining Epoch [98/98], Loss: 0.3641
# Retraining finished.

# %%
print(f"\n===================== Final Evaluation with Retrained Model =====================")
final_model.eval() # 평가 모드로 설정

# 테스트 데이터 준비 (기존 코드와 동일)
feature_cols = ['x_std', 'y_std', 'z_std', 'magnitude_std']
X_test, y_test = get_frames(test_df, frame_size, hop_size)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# ✨ final_model ✨을 사용하여 최종 예측 수행
all_test_predictions = []
all_test_labels = []
with torch.no_grad():
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        outputs = final_model(inputs)
        _, predicted = torch.max(outputs, 1)
        all_test_predictions.extend(predicted.cpu().numpy())
        all_test_labels.extend(labels.numpy())
        
# 최종 결과 분석 및 시각화 (기존 코드와 동일)
from sklearn.metrics import classification_report, confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

print("\n### Final Test Set Classification Report ###")
print(classification_report(all_test_labels, all_test_predictions, target_names=label_encoder.classes_))

print("\n### Final Test Set Confusion Matrix ###")
mat = confusion_matrix(all_test_labels, all_test_predictions)
plot_confusion_matrix(
    conf_mat=mat,
    class_names=label_encoder.classes_,
    show_normed=True,
    figsize=(7, 7)
)
plt.show()
# Out:
# ===================== Final Evaluation with Retrained Model =====================
#
# ### Final Test Set Classification Report ###
#               precision    recall  f1-score   support
#
#   Downstairs       0.74      0.07      0.13       384
#      Jogging       0.99      0.90      0.94      1313
#      Sitting       0.56      0.95      0.71        63
#     Standing       0.00      0.00      0.00        48
#     Upstairs       0.31      0.87      0.45       405
#      Walking       0.83      0.65      0.73      1328
#
#     accuracy                           0.70      3541
#    macro avg       0.57      0.57      0.49      3541
# weighted avg       0.80      0.70      0.70      3541
#
#
# ### Final Test Set Confusion Matrix ###
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\c\Desktop\ML programming\venv\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
