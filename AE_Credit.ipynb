# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# %%
# 1. 데이터 로드 및 전처리
# 신용카드 데이터셋을 불러옵니다.

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML programming/data/creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
# 결측치 홗인
df.isnull().values.any()
# Out:
# np.False_

# %%
LABELS = ["Normal", "Fraud"]

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# /tmp/ipython-input-3573906420.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd.value_counts(df['Class'], sort = True)
# Text(0, 0.5, 'Frequency')

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
# 모델을 오직 정상 거래기록으로만 훈련
# 정상 거래기록을 테스트셋에 넣으면 모델의 성능을 평가

# %%
RANDOM_SEED = 42

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train.shape
# Out:
# (227451, 29)

# %%
# 테스트 레이블을 남겨두는 이유는 나중에 정확도를 비교하기 위해서임

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train, X_train,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_split = 0.1)
# Out:
# Epoch 1/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.1071 - val_loss: 0.8915
# Epoch 2/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.9211 - val_loss: 0.8607
# Epoch 3/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8570 - val_loss: 0.8445
# Epoch 4/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8568 - val_loss: 0.8354
# Epoch 5/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8485 - val_loss: 0.8286
# Epoch 6/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8596 - val_loss: 0.8254
# Epoch 7/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8345 - val_loss: 0.8229
# Epoch 8/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.8419 - val_loss: 0.8207
# Epoch 9/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8423 - val_loss: 0.8189
# Epoch 10/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8380 - val_loss: 0.8180
# Epoch 11/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8342 - val_loss: 0.8170
# Epoch 12/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8780 - val_loss: 0.8163
# Epoch 13/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8313 - val_loss: 0.8158
# Epoch 14/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8194 - val_loss: 0.8146
# Epoch 15/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8389 - val_loss: 0.8129
# Epoch 16/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8266 - val_loss: 0.8123
# Epoch 17/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8388 - val_loss: 0.8120
# Epoch 18/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8256 - val_loss: 0.8116
# Epoch 19/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8316 - val_loss: 0.8120
# Epoch 20/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8217 - val_loss: 0.8113
# Epoch 21/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8213 - val_loss: 0.8112
# Epoch 22/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8371 - val_loss: 0.8111
# Epoch 23/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8287 - val_loss: 0.8109
# Epoch 24/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8318 - val_loss: 0.8106
# Epoch 25/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8265 - val_loss: 0.8106
# Epoch 26/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8178 - val_loss: 0.8105
# Epoch 27/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8296 - val_loss: 0.8103
# Epoch 28/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8247 - val_loss: 0.8101
# Epoch 29/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8373 - val_loss: 0.8101
# Epoch 30/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.8128 - val_loss: 0.8099
# Epoch 31/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8246 - val_loss: 0.8098
# Epoch 32/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8117 - val_loss: 0.8099
# Epoch 33/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8213 - val_loss: 0.8098
# Epoch 34/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8227 - val_loss: 0.8095
# Epoch 35/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8166 - val_loss: 0.8096
# Epoch 36/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8073 - val_loss: 0.8097
# Epoch 37/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8384 - val_loss: 0.8094
# Epoch 38/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8131 - val_loss: 0.8094
# Epoch 39/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8398 - val_loss: 0.8093
# Epoch 40/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.8318 - val_loss: 0.8093
# Epoch 41/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.8317 - val_loss: 0.8092
# Epoch 42/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8451 - val_loss: 0.8093
# Epoch 43/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8202 - val_loss: 0.8091
# Epoch 44/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8149 - val_loss: 0.8091
# Epoch 45/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8266 - val_loss: 0.8090
# Epoch 46/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8325 - val_loss: 0.8090
# Epoch 47/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.8209 - val_loss: 0.8090
# Epoch 48/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8350 - val_loss: 0.8090
# Epoch 49/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8102 - val_loss: 0.8089
# Epoch 50/50
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.8163 - val_loss: 0.8088

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.850767      0.001720
# std                3.715212      0.041443
# min                0.047101      0.000000
# 25%                0.260597      0.000000
# 50%                0.440566      0.000000
# 75%                0.701046      0.000000
# max              258.453861      1.000000

# %%
error_df.head()
# Out:
#         reconstruction_error  true_class
# 43428              81.179796           1
# 49906               0.884619           0
# 29474               0.338895           0
# 276481              0.406928           0
# 278846              0.200641           0

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.14      0.37      0.20        98
#
#     accuracy                           1.00     56962
#    macro avg       0.57      0.68      0.60     56962
# weighted avg       1.00      1.00      1.00     56962
